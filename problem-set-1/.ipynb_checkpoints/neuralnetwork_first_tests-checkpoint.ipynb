# %%
import numpy as np
from nn_wrapper import NeuralNetworkWrapper
from sklearn import datasets
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
#from nn_basic_functions import normalize_data

# %%
breast_cancer_data = datasets.load_breast_cancer()

X = breast_cancer_data['data']
y = breast_cancer_data['target']

from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
# tak nie wolno :(
X = ss.fit_transform(X)

# %%
# TODO: where the data should be normalized/standardised?
#X_train, X_test = normalize_data(X_train, X_test)
# imo this should work like this: NeuralNetwork(X_train, y_train, X_test, y_test)
#
nn = NeuralNetworkWrapper(X.shape[1], [10, 10, 1], ['relu', 'relu', 'sigmoid'], 0.001, 100)

# %%
# "reset weights" functionality?
# shuffling batches on each epoch
nn.train(X, y, epochs=1000)
# Out:
# Loss after 1 epochs: 0.7666259408039819
# Loss after 101 epochs: 0.46049928306380183
# Loss after 201 epochs: 0.28742937204655183
# Loss after 301 epochs: 0.19621323053231968
# Loss after 401 epochs: 0.13478635129328975
# Loss after 501 epochs: 0.0911186285778778
# Loss after 601 epochs: 0.06294527475180114
# Loss after 701 epochs: 0.04543954272948998
# Loss after 801 epochs: 0.03360199836653204
# Loss after 901 epochs: 0.025274633860858972

# %%
nn.plot_loss()

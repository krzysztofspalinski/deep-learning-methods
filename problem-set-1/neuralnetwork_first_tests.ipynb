# %%
import numpy as np
from nn_wrapper import NeuralNetworkWrapper
from sklearn import datasets
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
#from nn_basic_functions import normalize_data

# %%
breast_cancer_data = datasets.load_breast_cancer()

# %%
breast_cancer_data = datasets.load_breast_cancer()

X = breast_cancer_data['data']
y = breast_cancer_data['target']

from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
# tak nie wolno :(
X = ss.fit_transform(X)

# %%
# TODO: where the data should be normalized/standardised?
#X_train, X_test = normalize_data(X_train, X_test)
# imo this should work like this: NeuralNetwork(X_train, y_train, X_test, y_test)
#
nn = NeuralNetworkWrapper(X.shape[1], [10, 10, 1], ['relu', 'relu', 'sigmoid'], 0.001, 100)

# %%
# "reset weights" functionality?
# shuffling batches on each epoch
nn.train(X, y, epochs=1000)
# Out:
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# Loss after 1 epochs: 1.123002006684351
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# Loss after 101 epochs: 0.5919746655077003
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# Loss after 201 epochs: 0.3864681927791237
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# Loss after 301 epochs: 0.2814124322059902
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# Loss after 401 epochs: 0.21476506861619118
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# Loss after 501 epochs: 0.17962178327737538
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# Loss after 601 epochs: 0.1530954714573488
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# Loss after 701 epochs: 0.13477804299589374
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# Loss after 801 epochs: 0.12310739857749788
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# Loss after 901 epochs: 0.11244691823714836
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 100)
# (1, 12)

# %%
nn.plot_loss()

# %%
y.shape
# Out:
# (569,)
